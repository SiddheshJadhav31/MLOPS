# %%
# Minimum , Maximum, Median , Q1, Q3, IQR
# Outlier Detection using Pyhton

# %%
import numpy as np

# %%
list_marks = [45,36,75,36,78,43,55,89,69,98,99,67.72,54]
minimum,Q1,median,Q3,maximum = np.quantile(list_marks, [0 ,0.25,0.50,0.75,1.0])

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 33.0

# %%
lower = Q1 -1.5* IQR
higher = Q3+ 1.5*IQR

# %%
lower
# Out:
# np.float64(-4.5)

# %%
higher
# Out:
# np.float64(127.5)

# %%
list_marks = [45,36,75,36,78,43,55,89,69,98,99,67.72,54]

# %%
import seaborn as sns
sns.boxplot(list_marks)
# Out:
# <Axes: >

# %%
list_marks = [45,36,75,36,78,43,55,89,69,98,99,67.72,54,100, 130,120,150,200]

# %%
sns.boxplot(list_marks)
# Out:
# <Axes: >
